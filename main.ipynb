# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import src.webscrapping_cleaning as wb
import src.downloading as dl
import src.visualizations as vs

# %%
df=wb.request_url('https://www.directoalpaladar.com/actualidad-1/estas-han-sido-diez-recetas-virales-tiktok-2022')

# %%
df
# Out:
# <!DOCTYPE html>
#
# <html lang="es">
# <head>
# <script>
#  var country = 'ES';
#  var isSpainOrLatamUser = true;
# </script>
# <title>Estas han sido las diez recetas más virales de TikTok de 2022</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Lo sentimos por quienes estén hartos ya de leer listados recopilatorios del año, pero en estas fechas es lo que toca. Más allá de tops subjetivos, al menos..." name="description"/>
# <meta content="Redes Sociales, Directo al Paladar, Tik Tok, Recetario de cocina, Actualidad" name="news_keywords"/>
# <meta content="noodp" name="robots"/>
# <meta content="100000716994885" property="fb:admins"/>
# <meta content="41182117378" property="fb:pages"/>
# <meta content="357721611901" property="fb:app_id"/>
# <meta content="Directo al Paladar" name="application-name"/>
# ...

# %%
df=wb.labels(df)

# %%
df
# Out:
# {'1. Pan nube': 'Tiene ya unos añitos desde que la vimos por primera vez en las redes, pero ha cobrado un nuevo impulso con el auge de TikTok. Las recetas bajas en calorías o que prometen adelgazar y tener un cuerpo más atlético no fallan a la hora de viralizarse, y el cloud bread o pan nube sigue siendo el rey, en paralelo a la fama de las dietas keto. De pan tiene poco, pero hay que reconocer que se prepara muy rápido y es una forma sencilla de tomar proteínas y reducir los hidratos de carbono simples, por ejemplo como alternativa al pan de molde blanco industrial. Ingredientes para unas 9 unidades. 3 huevos L, 100 g de queso crema, 1/4 cucharadita de bicarbonato sódico.\nElaboración. Empezamos precalentando el horno a 150ºC. Después, separando las claras de las yemas de los huevos. Batimos las yemas con el queso crema hasta obtener una masa homogénea y suave. En un bol aparte batimos las claras a punto de nieve con el bicarbonato. Mezclamos ambas masas con la ayuda de una espátula
# ...

# %%
df=wb.scrapping1(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df=wb.scrapping1(df)
#
# TypeError: scrapping1() takes 0 positional arguments but 1 was given
